# %%
import requests
import pandas as pd
URL ='https://data.seattle.gov/api/views/2khk-5ukd/rows.csv?accessType=DOWNLOAD'
df = pd.read_csv(URL)

# %%
#Read dataframe columns
df_col = sorted(df.columns)

# %%
#Read dataframe columns data type
df_col_type = list(df[df_col].dtypes)

# %%
def test_create_dataframe(df):
    df_col_test = sorted(df.columns)
    df_col_type_test = list(df[df_col_test].dtypes)
    
    #count row
    row = df.shape[0]
    
    #check if match the requirements
    if (df_col_test == df_col and df_col_type_test == df_col_type and row >= 10):
        return True
    else:
        return False

# %%
test_create_dataframe(df)
# Out:
# True

# %%
#Test add new column into dataframe to see if match the requirements
address = None  
df['Address'] = address

# %%
df
# Out:
#                            Department    Last Name   First Name  \
# 0              Information Technology           Yu      Chi Shu
# 1              Information Technology           Ng     Jennifer
# 2              Information Technology     Brunzell         Suzy
# 3              Information Technology  Delos Reyes       Nelson
# 4              Information Technology       Nobles     Laurence
# 5              Information Technology         Heil       Braden
# 6              Information Technology       Devier          Ian
# 7              Information Technology       Nguyen         Minh
# 8              Information Technology      Johnson    Gwendolyn
# 9              Information Technology        Adair         Chad
# 10             Information Technology        Hagen      Kenneth
# 11             Information Technology        Adams        Robby
# 12             Information Technology      Zemanek         Greg
# 13             Information Technology         Wong       Geramy
# 14             Information Technology       Miller      Matthew
# 15             Information Technology      Kessler      Annette
# 16             Information Technology        Clark         John
# 17             Information Technology        Yates          Jon
# 18             Information Technology         Rice        Craig
# 19             Information Technology      Richter         Eric
# 20             Information Technology         Flin     Kimberly
# 21             Information Technology        Zwink       Donald
# 22             Information Technology      Lindsey     Gretchan
# 23             Information Technology          Kim        Glenn
# 24             Information Technology      Camarda     Michelle
# 25             Legislative Department         Peha       Joseph
# 26             Legislative Department    Dall'Osto       Alisha
# 27             Legislative Department      Samuels     Jennifer
# 28     Seattle Dept of Human Resource       Ardena          Amy
# 29     Seattle Dept of Human Resource          Lee       Soo Ah
# ...                               ...          ...          ...
# 12495                 Fire Department       Jewell       Duncan
# 12496                 Fire Department      Johnson      Douglas
# 12497                 Fire Department     Batayola         Luis
# 12498                 Fire Department     Sorensen      Juliann
# 12499                 Fire Department        Smith      Stanley
# 12500                 Fire Department      Hartill       Mathew
# 12501                 Fire Department    Lenseigne      Anthony
# 12502                 Fire Department       Mahnke          Jay
# 12503                 Fire Department      Mellein         Mark
# 12504                 Fire Department        Woods        Tyler
# 12505                 Fire Department     O'Connor        James
# 12506                 Fire Department    Schulberg       Darren
# 12507                 Fire Department        Lopez       Landon
# 12508                 Fire Department     Browning     Nicholas
# 12509                 Fire Department      Hammond        Jacob
# 12510                 Fire Department        Keane      Randall
# 12511                 Fire Department  Rondestvedt         Sean
# 12512                 Fire Department        Ellis         Ryan
# 12513                 Fire Department      Russell      Michael
# 12514                 Fire Department       Taylor       Cheryl
# 12515                 Fire Department        Kyles      Patrick
# 12516                 Fire Department        Engel      Bradley
# 12517                 Fire Department   Mollenkopf       Trevor
# 12518                 Fire Department      Carlson         Cody
# 12519                 Fire Department      Lombard  Christopher
# 12520                 Fire Department       Barber        David
# 12521                 Fire Department        Breit      Barbara
# 12522                 Fire Department     Scoggins       Harold
# 12523                 Fire Department        Ducay        Agnes
# 12524                 Fire Department      Goodall       George
#
#                            Job Title  Hourly Rate  Address
# 0         Info Technol Prof A,Exempt        66.226    None
# 1             Info Technol Prof B-BU        53.642    None
# 2         Info Technol Prof A,Exempt        63.048    None
# 3             Info Technol Prof B-BU        58.842    None
# 4             IT Prgmmer Anlyst-Spec        40.920    None
# 5             Info Technol Prof B-BU        60.048    None
# 6                      Video Spec II        40.480    None
# 7             Info Technol Prof B-BU        57.959    None
# 8                  Mgmt Systs Anlyst        40.480    None
# 9             Telecom Syst Installer        36.280    None
# 10            Info Technol Prof B-BU        60.778    None
# 11            Info Technol Prof B-BU        54.273    None
# 12            Info Technol Prof B-BU        53.378    None
# 13            Info Technol Prof B-BU        57.695    None
# 14            Info Technol Prof C-BU        46.533    None
# 15            Info Technol Prof B-BU        56.437    None
# 16            Info Technol Prof B-BU        53.186    None
# 17         Info Technol Systs Anlyst        42.920    None
# 18            Info Technol Prof B-BU        56.132    None
# 19          StratAdvsr2,Info Technol        57.500    None
# 20          StratAdvsr2,Info Technol        57.622    None
# 21             Info Technol Prof A *        61.979    None
# 22                     StratAdvsr2 *        52.000    None
# 23             Info Technol Prof A *        61.360    None
# 24              Mgmt Systs Anlyst,Sr        42.920    None
# 25            StratAdvsr-Legislative        41.492    None
# 26                  Legislative Asst        34.000    None
# 27                  Legislative Asst        45.084    None
# 28                Admin Staff Anlyst        37.590    None
# 29             Personnel Anlyst Trne        32.170    None
# ...                              ...           ...     ...
# 12495            Fire Capt-90.46 Hrs        54.450    None
# 12496           Fire Lieut-90.46 Hrs        48.070    None
# 12497           Fire Lieut-90.46 Hrs        49.550    None
# 12498          Fireftr-Ap Drvr-90.46        45.120    None
# 12499          Fireftr-Ap Drvr-90.46        44.380    None
# 12500          Fireftr-Ap Drvr-90.46        45.120    None
# 12501          Fireftr-Ap Drvr-90.46        44.380    None
# 12502           Fire Lieut-90.46 Hrs        48.810    None
# 12503              Fireftr-90.46 Hrs        39.760    None
# 12504              Fireftr-90.46 Hrs        39.760    None
# 12505          Fireftr-Ap Drvr-90.46        44.380    None
# 12506          Fireftr-Ap Drvr-90.46        45.120    None
# 12507              Fireftr-90.46 Hrs        38.280    None
# 12508          Fireftr-Ap Drvr-90.46        40.130    None
# 12509              Fireftr-90.46 Hrs        36.430    None
# 12510          Fireftr-Ap Drvr-90.46        44.380    None
# 12511          Fireftr-Ap Drvr-90.46        43.460    None
# 12512    Fireftr-ParamedTechSr-90.46        48.450    None
# 12513    Fireftr-ParamedTechSr-90.46        48.450    None
# 12514    Fireftr-ParamedTechSr-90.46        50.850    None
# 12515    Fireftr-ParamedTechSr-90.46        49.370    None
# 12516              Fireftr-90.46 Hrs        39.020    None
# 12517              Fireftr-90.46 Hrs        30.880    None
# 12518              Fireftr-90.46 Hrs        30.880    None
# 12519  Fire Battalion Chief-91.4 Hrs        62.600    None
# 12520              Fireftr-90.46 Hrs        39.760    None
# 12521             Trng&Ed Coord,Asst        29.890    None
# 12522                     Executive4       110.806    None
# 12523                    Permit Tech        31.630    None
# 12524        Fire Protection Engr,Sr        57.810    None
#
# [12525 rows x 6 columns]

# %%
test_create_dataframe(df)
# Out:
# False
